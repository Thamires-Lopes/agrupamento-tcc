# %%
# Análise de dados de silhueta do csv formado excluindo correlação maior que 0.8

# %%
import pandas as pd
from sklearn.cluster import KMeans
from yellowbrick.cluster import SilhouetteVisualizer
import matplotlib.pyplot as plt
import warnings

# %%
pd.set_option('display.max_columns',None)
warnings.filterwarnings("ignore")

# %%
X = pd.read_csv('../dados_processados/cursos-pos-processamento.csv',sep=';')

# %%
X.shape
# Out:
# (6511, 97)

# %%
X.columns
# Out:
# Index(['no_cine_area_geral_agricultura,_silvicultura,_pesca_e_veterinaria',
#        'no_cine_area_geral_artes_e_humanidades',
#        'no_cine_area_geral_ciencias_naturais,_matematica_e_estatistica',
#        'no_cine_area_geral_ciencias_sociais,_comunicacao_e_informacao',
#        'no_cine_area_geral_computacao_e_tecnologias_da_informacao_e_comunicacao_(tic)',
#        'no_cine_area_geral_educacao',
#        'no_cine_area_geral_engenharia,_producao_e_construcao',
#        'no_cine_area_geral_negocios,_administracao_e_direito',
#        'no_cine_area_geral_saude_e_bem-estar', 'no_cine_area_geral_servicos',
#        'tp_grau_academico_bacharelado', 'tp_grau_academico_licenciatura',
#        'tp_grau_academico_tecnologico', 'co_regiao', 'co_uf',
#        'tp_categoria_administrativa', 'co_ies', 'qt_vg_total',
#        'qt_vg_total_diurno', 'qt_vg_total_noturno', 'qt_vg_nova',
#        'qt_vg_remanesc', 'qt_inscrito_total_diurno',
#        'qt_inscrito_total_noturno', 'qt_insc_vg_nova', 'qt_insc_vg_remanesc',
#        'qt_ing_fem', 'qt_ing_masc', 'qt_ing_diurno', 'qt_ing_noturno',
#        'qt_ing_vg_nova', 'qt_ing_vestibular', 'qt_ing_enem',
#        'qt_ing_vg_remanesc', 'qt_ing_branca', 'qt_ing_preta', 'qt_ing_parda',
#        'qt_ing_amarela', 'qt_ing_cornd', 'qt_mat_fem', 'qt_mat_masc',
#        'qt_mat_diurno', 'qt_mat_noturno', 'qt_mat_60_mais', 'qt_mat_branca',
#        'qt_mat_preta', 'qt_mat_parda', 'qt_mat_amarela', 'qt_mat_indigena',
#        'qt_mat_cornd', 'qt_conc_fem', 'qt_conc_masc', 'qt_conc_diurno',
#        'qt_conc_noturno', 'qt_conc_branca', 'qt_conc_preta', 'qt_conc_parda',
#        'qt_conc_cornd', 'qt_ing_nacbras', 'qt_mat_nacbras',
#        'qt_mat_nacestrang', 'qt_conc_nacbras', 'qt_aluno_deficiente',
#        'qt_ing_deficiente', 'qt_ing_reserva_vaga', 'qt_ing_rvredepublica',
#        'qt_ing_rvetnico', 'qt_ing_rvsocial_rf', 'qt_mat_reserva_vaga',
#        'qt_mat_rvredepublica', 'qt_mat_rvetnico', 'qt_mat_rvpdef',
#        'qt_mat_rvsocial_rf', 'qt_conc_reserva_vaga', 'qt_conc_rvredepublica',
#        'qt_conc_rvetnico', 'qt_conc_rvsocial_rf', 'qt_sit_trancada',
#        'qt_sit_desvinculado', 'qt_sit_transferido', 'qt_ing_procescpublica',
#        'qt_ing_procescprivada', 'qt_mat_procescpublica',
#        'qt_mat_procescprivada', 'qt_conc_procescpublica',
#        'qt_conc_procescprivada', 'qt_apoio_social', 'qt_ing_apoio_social',
#        'qt_conc_apoio_social', 'qt_ativ_extracurricular',
#        'qt_ing_ativ_extracurricular', 'qt_mat_ativ_extracurricular',
#        'qt_conc_ativ_extracurricular', 'co_curso', 'no_curso', 'enade_faixa',
#        'cpc_faixa'],
#       dtype='object')

# %%
X_to_train = X.drop(['no_curso','co_curso'],axis=1)

# %%
# Criando e mostrando os gráficos de silhueta de k=2 até k=20

min_clusters = 2
max_clusters = 20

for n_clusters in range(min_clusters, max_clusters + 1):
    kmeans = KMeans(n_clusters=n_clusters, random_state=42, n_init=100)
    kmeans.fit(X_to_train)
    
    visualizer = SilhouetteVisualizer(kmeans)
    visualizer.fit(X_to_train)
    visualizer.show()
