# %%
import pandas as pd

# %%
cluster_original_k_5 = {
    0 : ["recife_bacharelado_agronomia",
         "recife_licenciatura_ciencias_biologicas",
         "recife_licenciatura_matematica",
         "recife_bacharelado_medicina_veterinaria",
         "recife_licenciatura_quimica"],
    1 : ["recife_bacharelado_ciencias_biologicas",
        "recife_bacharelado_ciencias_do_consumo",
        "recife_bacharelado_engenharia_agricola_e_ambiental",
        "recife_bacharelado_engenharia_de_pesca",
        "recife_bacharelado_engenharia_florestal",
        "recife_licenciatura_fisica",
        "recife_bacharelado_zootecnia",
        "serra_talhada_bacharelado_administracao",
        "serra_talhada_bacharelado_agronomia",
        "serra_talhada_bacharelado_ciencias_biologicas",
        "serra_talhada_bacharelado_ciencias_economicas",
        "serra_talhada_bacharelado_engenharia_de_pesca",
        "serra_talhada_licenciatura_letras_-_portugues_e_ingles",
        "serra_talhada_licenciatura_quimica",
        "serra_talhada_bacharelado_sistema_de_informacao",
        "serra_talhada_bacharelado_zootecnia"],
    2 : ["cabo_de_santo_agostinho_bacharelado_engenharia_civil",
        "cabo_de_santo_agostinho_bacharelado_engenharia_de_materiais",
        "cabo_de_santo_agostinho_bacharelado_engenharia_eletronica",
        "cabo_de_santo_agostinho_bacharelado_engenharia_eletrica",
        "cabo_de_santo_agostinho_bacharelado_engenharia_mecanica"],
    3 : ["belo_jardim_bacharelado_engenharia_de_computacao",
        "belo_jardim_bacharelado_engenharia_de_controle_e_automacao",
        "belo_jardim_bacharelado_engenharia_hidrica",
        "belo_jardim_bacharelado_engenharia_quimica",
        "recife_bacharelado_agroecologia",
        "recife_tecnologico_aquicultura",
        "recife_licenciatura_ciencias_agricolas",
        "recife_bacharelado_economia_domestica",
        "recife_bacharelado_engenharia_ambiental"],
    4 : ["recife_bacharelado_administracao",
        "recife_bacharelado_ciencia_da_computacao",
        "recife_bacharelado_ciencias_economicas",
        "recife_bacharelado_ciencias_sociais",
        "recife_licenciatura_computacao",
        "recife_licenciatura_educacao_fisica",
        "recife_bacharelado_gastronomia",
        "recife_licenciatura_historia",
        "recife_licenciatura_letras_-_portugues_e_espanhol",
        "recife_licenciatura_pedagogia",
        "recife_bacharelado_sistema_de_informacao"]
}

# %%
df = pd.DataFrame([(label, curso) for label, cursos in cluster_original_k_5.items() for curso in cursos], columns=["label", "no_curso"])

# %%
df
# Out:
#     label                                           no_curso
# 0       0                       recife_bacharelado_agronomia
# 1       0            recife_licenciatura_ciencias_biologicas
# 2       0                     recife_licenciatura_matematica
# 3       0            recife_bacharelado_medicina_veterinaria
# 4       0                        recife_licenciatura_quimica
# 5       1             recife_bacharelado_ciencias_biologicas
# 6       1             recife_bacharelado_ciencias_do_consumo
# 7       1  recife_bacharelado_engenharia_agricola_e_ambie...
# 8       1             recife_bacharelado_engenharia_de_pesca
# 9       1            recife_bacharelado_engenharia_florestal
# 10      1                         recife_licenciatura_fisica
# 11      1                       recife_bacharelado_zootecnia
# 12      1            serra_talhada_bacharelado_administracao
# 13      1                serra_talhada_bacharelado_agronomia
# ...

# %%
df.to_csv("dados_originais/cluster_original_k_5.csv", index=False)
