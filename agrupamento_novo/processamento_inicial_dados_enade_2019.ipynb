# %%
import pandas as pd
from unidecode import unidecode

# %%
excel_file_path_enade = 'dados/Conceito_Enade_2019.xlsx'
enade = pd.read_excel(excel_file_path_enade)

# %% [markdown]
# # Enade

# %% [markdown]
# ### Funções

# %%
def remove_acentos(texto):
    return unidecode(str(texto))

# %%
def minusculo(texto):
    texto = texto.strip()
    texto = texto.replace('*', '')
    texto = texto.replace(' ', '_')
    return str(texto).lower()

# %%
def is_inteiro(valor):
    try:
        int_valor = int(valor)
        return True
    except (ValueError, TypeError):
        return False

# %%
def converter_para_int(valor):
    try:
        return int(valor)
    except ValueError:
        return 0

# %% [markdown]
# ### Análise e limpeza dos dados

# %%
enade
# Out:
#        Ano  Código da Área                    Área de Avaliação  \
# 0     2019               5                 MEDICINA VETERINÁRIA
# 1     2019               5                 MEDICINA VETERINÁRIA
# 2     2019               5                 MEDICINA VETERINÁRIA
# 3     2019               5                 MEDICINA VETERINÁRIA
# 4     2019               5                 MEDICINA VETERINÁRIA
# ...    ...             ...                                  ...
# 8363  2019            6410  TECNOLOGIA EM SEGURANÇA NO TRABALHO
# 8364  2019            6410  TECNOLOGIA EM SEGURANÇA NO TRABALHO
# 8365  2019            6410  TECNOLOGIA EM SEGURANÇA NO TRABALHO
# 8366  2019            6410  TECNOLOGIA EM SEGURANÇA NO TRABALHO
# 8367  2019            6410  TECNOLOGIA EM SEGURANÇA NO TRABALHO
#
#       Código da IES                                       Nome da IES  \
# 0                 1               UNIVERSIDADE FEDERAL DE MATO GROSSO
# 1                 1               UNIVERSIDADE FEDERAL DE MATO GROSSO
# 2                 2                          UNIVERSIDADE DE BRASÍLIA
# 3                 3                   UNIVERSIDADE FEDERAL DE SERGIPE
# 4                 3                   UNIVERSIDADE FEDERAL DE SERGIPE
# ...             ...                                               ...
# 8363           4169                  Faculdade Estácio de Carapicuíba
# 8364           4277  FACULDADE ESTÁCIO DO AMAZONAS - ESTÁCIO AMAZONAS
# 8365           4460              FACULDADE DOM PEDRO II DE TECNOLOGIA
# 8366          17115                             FACULDADE TRÊS MARIAS
# 8367          18023                     FACULDADE UNINASSAU PETROLINA
#
#              Sigla da IES Organização Acadêmica     Categoria Administrativa  \
# 0                    UFMT          Universidade              Pública Federal
# 1                    UFMT          Universidade              Pública Federal
# 2                     UNB          Universidade              Pública Federal
# 3                     UFS          Universidade              Pública Federal
# 4                     UFS          Universidade              Pública Federal
# ...                   ...                   ...                          ...
# 8363  ESTÁCIO CARAPICUÍBA             Faculdade  Privada com fins lucrativos
# 8364     ESTÁCIO AMAZONAS             Faculdade  Privada com fins lucrativos
# 8365                  FAB             Faculdade  Privada com fins lucrativos
# 8366                  FTM             Faculdade  Privada com fins lucrativos
# 8367                  NaN             Faculdade  Privada com fins lucrativos
#
#       Código do Curso Modalidade de Ensino  ...  Sigla da UF  \
# 0                  37  Educação Presencial  ...           MT
# 1              100763  Educação Presencial  ...           MT
# 2               18031  Educação Presencial  ...           DF
# 3             1108067  Educação Presencial  ...           SE
# 4             1321453  Educação Presencial  ...           SE
# ...               ...                  ...  ...          ...
# 8363          1130185  Educação Presencial  ...           SP
# 8364          1056450  Educação Presencial  ...           AM
# 8365          1158603  Educação Presencial  ...           BA
# 8366          1183765  Educação Presencial  ...           PB
# 8367          1206480  Educação Presencial  ...           PE
#
#      Nº de Concluintes Inscritos Nº  de Concluintes Participantes  \
# 0                             23                               20
# 1                             46                               39
# 2                            129                              119
# 3                             47                               39
# 4                             28                               25
# ...                          ...                              ...
# 8363                           7                                0
# 8364                           1                                1
# 8365                           1                                1
# 8366                           8                                8
# 8367                           9                                9
#
#       Nota Bruta - FG  Nota Padronizada - FG  Nota Bruta - CE  \
# 0             42.8150                 2.7573          57.8000
# 1             42.1128                 2.6390          55.7282
# 2             50.6050                 4.0697          59.0025
# 3             45.7744                 3.2559          56.9667
# 4             43.5400                 2.8795          51.7800
# ...               ...                    ...              ...
# 8363              NaN                    NaN              NaN
# 8364              NaN                    NaN              NaN
# 8365              NaN                    NaN              NaN
# 8366          30.5500                 3.4211          35.4750
# 8367          35.7111                 5.0000          41.0667
#
#       Nota Padronizada - CE  Conceito Enade (Contínuo)  \
# 0                    3.1363                     3.0415
# 1                    2.7652                     2.7336
# 2                    3.3516                     3.5312
# 3                    2.9870                     3.0542
# 4                    2.0580                     2.2634
# ...                     ...                        ...
# 8363                    NaN                        NaN
# 8364                    NaN                        NaN
# 8365                    NaN                        NaN
# 8366                 2.6227                     2.8223
# 8367                 4.6112                     4.7084
#
#       Conceito Enade (Faixa)  Observação
# 0                          4         NaN
# 1                          3         NaN
# 2                          4         NaN
# 3                          4         NaN
# 4                          3         NaN
# ...                      ...         ...
# 8363                      SC         NaN
# 8364                      SC         NaN
# 8365                      SC         NaN
# 8366                       3         NaN
# 8367                       5         NaN
#
# [8368 rows x 22 columns]

# %% [markdown]
# #### Ajustando nomes das colunas e linhas

# %%
colunas = enade.columns
for coluna in colunas:
    print(coluna)
# Out:
# Ano
# Código da Área
# Área de Avaliação
# Código da IES
# Nome da IES
# Sigla da IES
# Organização Acadêmica
# Categoria Administrativa
# Código do Curso
# Modalidade de Ensino
# Código do Município
# Município do Curso
# Sigla da UF
# Nº de Concluintes Inscritos
# Nº  de Concluintes Participantes
# Nota Bruta - FG
# Nota Padronizada - FG
# Nota Bruta - CE
# Nota Padronizada - CE
# Conceito Enade (Contínuo)
# Conceito Enade (Faixa)
# Observação

# %%
enade.columns = [minusculo(remove_acentos(col)) for col in enade.columns]

# %%
colunas_categoricas = enade.select_dtypes(include=['object']).columns
for coluna in colunas_categoricas:
    enade[coluna] = enade[coluna].apply(remove_acentos)
    enade[coluna] = enade[coluna].apply(minusculo)

# %%
colunas = enade.columns
for coluna in colunas:
    print(coluna)
# Out:
# ano
# codigo_da_area
# area_de_avaliacao
# codigo_da_ies
# nome_da_ies
# sigla_da_ies
# organizacao_academica
# categoria_administrativa
# codigo_do_curso
# modalidade_de_ensino
# codigo_do_municipio
# municipio_do_curso
# sigla_da_uf
# no_de_concluintes_inscritos
# no__de_concluintes_participantes
# nota_bruta_-_fg
# nota_padronizada_-_fg
# nota_bruta_-_ce
# nota_padronizada_-_ce
# conceito_enade_(continuo)
# conceito_enade_(faixa)
# observacao

# %% [markdown]
# #### Ajustando dados da coluna conceito_enade_(faixa)

# %%
enade.shape
# Out:
# (8368, 22)

# %%
enade['conceito_enade_(faixa)'].unique()
# Out:
# array(['4', '3', '2', '5', '1', 'sc'], dtype=object)

# %%
# Limpando os dados para só manter as linhas em que 'conceito_enade_(faixa)' é inteiro e quem não é inteiro vira zero
enade['conceito_enade_(faixa)'] = enade['conceito_enade_(faixa)'].apply(converter_para_int)

# %%
enade['conceito_enade_(faixa)'].unique()
# Out:
# array([4, 3, 2, 5, 1, 0], dtype=int64)

# %%
enade.shape
# Out:
# (8368, 22)

# %% [markdown]
# #### Ajustando dados da coluna ano

# %%
enade.shape
# Out:
# (8368, 22)

# %%
enade['ano'].unique()
# Out:
# array([2019], dtype=int64)

# %%
# Limpando todos os dados que não seja do ano de 2022
enade_filtrado = enade.loc[enade['ano'] == 2019]

# %%
enade_filtrado['ano'].unique()
# Out:
# array([2019], dtype=int64)

# %%
enade.shape
# Out:
# (8368, 22)

# %% [markdown]
# #### Ajustando dados da coluna modalidade_de_ensino

# %%
enade_filtrado['modalidade_de_ensino'].unique()
# Out:
# array(['educacao_presencial', 'educacao_a_distancia'], dtype=object)

# %%
enade_filtrado.shape
# Out:
# (8368, 22)

# %%
enade_filtrado = enade_filtrado.loc[enade_filtrado['modalidade_de_ensino'] == 'educacao_presencial']

# %%
enade_filtrado['modalidade_de_ensino'].unique()
# Out:
# array(['educacao_presencial'], dtype=object)

# %%
enade_filtrado.shape
# Out:
# (8203, 22)

# %%
enade_filtrado
# Out:
#        ano  codigo_da_area                    area_de_avaliacao  \
# 0     2019               5                 medicina_veterinaria
# 1     2019               5                 medicina_veterinaria
# 2     2019               5                 medicina_veterinaria
# 3     2019               5                 medicina_veterinaria
# 4     2019               5                 medicina_veterinaria
# ...    ...             ...                                  ...
# 8363  2019            6410  tecnologia_em_seguranca_no_trabalho
# 8364  2019            6410  tecnologia_em_seguranca_no_trabalho
# 8365  2019            6410  tecnologia_em_seguranca_no_trabalho
# 8366  2019            6410  tecnologia_em_seguranca_no_trabalho
# 8367  2019            6410  tecnologia_em_seguranca_no_trabalho
#
#       codigo_da_ies                                       nome_da_ies  \
# 0                 1               universidade_federal_de_mato_grosso
# 1                 1               universidade_federal_de_mato_grosso
# 2                 2                          universidade_de_brasilia
# 3                 3                   universidade_federal_de_sergipe
# 4                 3                   universidade_federal_de_sergipe
# ...             ...                                               ...
# 8363           4169                  faculdade_estacio_de_carapicuiba
# 8364           4277  faculdade_estacio_do_amazonas_-_estacio_amazonas
# 8365           4460              faculdade_dom_pedro_ii_de_tecnologia
# 8366          17115                             faculdade_tres_marias
# 8367          18023                     faculdade_uninassau_petrolina
#
#              sigla_da_ies organizacao_academica     categoria_administrativa  \
# 0                    ufmt          universidade              publica_federal
# 1                    ufmt          universidade              publica_federal
# 2                     unb          universidade              publica_federal
# 3                     ufs          universidade              publica_federal
# 4                     ufs          universidade              publica_federal
# ...                   ...                   ...                          ...
# 8363  estacio_carapicuiba             faculdade  privada_com_fins_lucrativos
# 8364     estacio_amazonas             faculdade  privada_com_fins_lucrativos
# 8365                  fab             faculdade  privada_com_fins_lucrativos
# 8366                  ftm             faculdade  privada_com_fins_lucrativos
# 8367                  nan             faculdade  privada_com_fins_lucrativos
#
#       codigo_do_curso modalidade_de_ensino  ...  sigla_da_uf  \
# 0                  37  educacao_presencial  ...           mt
# 1              100763  educacao_presencial  ...           mt
# 2               18031  educacao_presencial  ...           df
# 3             1108067  educacao_presencial  ...           se
# 4             1321453  educacao_presencial  ...           se
# ...               ...                  ...  ...          ...
# 8363          1130185  educacao_presencial  ...           sp
# 8364          1056450  educacao_presencial  ...           am
# 8365          1158603  educacao_presencial  ...           ba
# 8366          1183765  educacao_presencial  ...           pb
# 8367          1206480  educacao_presencial  ...           pe
#
#      no_de_concluintes_inscritos no__de_concluintes_participantes  \
# 0                             23                               20
# 1                             46                               39
# 2                            129                              119
# 3                             47                               39
# 4                             28                               25
# ...                          ...                              ...
# 8363                           7                                0
# 8364                           1                                1
# 8365                           1                                1
# 8366                           8                                8
# 8367                           9                                9
#
#       nota_bruta_-_fg  nota_padronizada_-_fg  nota_bruta_-_ce  \
# 0             42.8150                 2.7573          57.8000
# 1             42.1128                 2.6390          55.7282
# 2             50.6050                 4.0697          59.0025
# 3             45.7744                 3.2559          56.9667
# 4             43.5400                 2.8795          51.7800
# ...               ...                    ...              ...
# 8363              NaN                    NaN              NaN
# 8364              NaN                    NaN              NaN
# 8365              NaN                    NaN              NaN
# 8366          30.5500                 3.4211          35.4750
# 8367          35.7111                 5.0000          41.0667
#
#       nota_padronizada_-_ce  conceito_enade_(continuo)  \
# 0                    3.1363                     3.0415
# 1                    2.7652                     2.7336
# 2                    3.3516                     3.5312
# 3                    2.9870                     3.0542
# 4                    2.0580                     2.2634
# ...                     ...                        ...
# 8363                    NaN                        NaN
# 8364                    NaN                        NaN
# 8365                    NaN                        NaN
# 8366                 2.6227                     2.8223
# 8367                 4.6112                     4.7084
#
#       conceito_enade_(faixa)  observacao
# 0                          4         NaN
# 1                          3         NaN
# 2                          4         NaN
# 3                          4         NaN
# 4                          3         NaN
# ...                      ...         ...
# 8363                       0         NaN
# 8364                       0         NaN
# 8365                       0         NaN
# 8366                       3         NaN
# 8367                       5         NaN
#
# [8203 rows x 22 columns]

# %% [markdown]
# #### Ajustando dados da coluna categoria_administrativa

# %%
enade_filtrado['categoria_administrativa'].unique()
# Out:
# array(['publica_federal', 'publica_estadual',
#        'privada_sem_fins_lucrativos', 'publica_municipal',
#        'privada_com_fins_lucrativos', 'especial'], dtype=object)

# %%
enade_filtrado.shape
# Out:
# (8203, 22)

# %%
categorias_desejadas = ['publica_federal', 'publica_estadual', 'publica_municipal']
enade_filtrado = enade_filtrado[enade_filtrado['categoria_administrativa'].isin(categorias_desejadas)]

# %%
enade_filtrado['categoria_administrativa'].unique()
# Out:
# array(['publica_federal', 'publica_estadual', 'publica_municipal'],
#       dtype=object)

# %%
enade_filtrado.shape
# Out:
# (1973, 22)

# %%
enade_filtrado
# Out:
#        ano  codigo_da_area                    area_de_avaliacao  \
# 0     2019               5                 medicina_veterinaria
# 1     2019               5                 medicina_veterinaria
# 2     2019               5                 medicina_veterinaria
# 3     2019               5                 medicina_veterinaria
# 4     2019               5                 medicina_veterinaria
# ...    ...             ...                                  ...
# 8336  2019            6405                 engenharia_florestal
# 8337  2019            6405                 engenharia_florestal
# 8338  2019            6405                 engenharia_florestal
# 8339  2019            6410  tecnologia_em_seguranca_no_trabalho
# 8353  2019            6410  tecnologia_em_seguranca_no_trabalho
#
#       codigo_da_ies                                        nome_da_ies  \
# 0                 1                universidade_federal_de_mato_grosso
# 1                 1                universidade_federal_de_mato_grosso
# 2                 2                           universidade_de_brasilia
# 3                 3                    universidade_federal_de_sergipe
# 4                 3                    universidade_federal_de_sergipe
# ...             ...                                                ...
# 8336           5701                    universidade_do_estado_do_amapa
# 8337          15059              universidade_federal_do_oeste_do_para
# 8338          23410  universidade_estadual_da_regiao_tocantina_do_m...
# 8339             32  universidade_estadual_de_ciencias_da_saude_de_...
# 8353           1166  instituto_federal_de_educacao,_ciencia_e_tecno...
#
#      sigla_da_ies                              organizacao_academica  \
# 0            ufmt                                       universidade
# 1            ufmt                                       universidade
# 2             unb                                       universidade
# 3             ufs                                       universidade
# 4             ufs                                       universidade
# ...           ...                                                ...
# 8336         ueap                                       universidade
# 8337        ufopa                                       universidade
# 8338      uemasul                                       universidade
# 8339      uncisal                                       universidade
# 8353         ifpb  instituto_federal_de_educacao,_ciencia_e_tecno...
#
#      categoria_administrativa  codigo_do_curso modalidade_de_ensino  ...  \
# 0             publica_federal               37  educacao_presencial  ...
# 1             publica_federal           100763  educacao_presencial  ...
# 2             publica_federal            18031  educacao_presencial  ...
# 3             publica_federal          1108067  educacao_presencial  ...
# 4             publica_federal          1321453  educacao_presencial  ...
# ...                       ...              ...                  ...  ...
# 8336         publica_estadual          1146839  educacao_presencial  ...
# 8337          publica_federal          1186268  educacao_presencial  ...
# 8338         publica_estadual          1208279  educacao_presencial  ...
# 8339         publica_estadual          1428361  educacao_presencial  ...
# 8353          publica_federal           123116  educacao_presencial  ...
#
#       sigla_da_uf no_de_concluintes_inscritos  \
# 0              mt                          23
# 1              mt                          46
# 2              df                         129
# 3              se                          47
# 4              se                          28
# ...           ...                         ...
# 8336           ap                          15
# 8337           pa                          46
# 8338           ma                          36
# 8339           al                          10
# 8353           pb                          45
#
#      no__de_concluintes_participantes  nota_bruta_-_fg  nota_padronizada_-_fg  \
# 0                                  20          42.8150                 2.7573
# 1                                  39          42.1128                 2.6390
# 2                                 119          50.6050                 4.0697
# 3                                  39          45.7744                 3.2559
# 4                                  25          43.5400                 2.8795
# ...                               ...              ...                    ...
# 8336                                6          44.2333                 2.1413
# 8337                               42          45.7119                 2.3895
# 8338                               33          48.6970                 2.8905
# 8339                               10          31.8200                 3.8097
# 8353                               43          35.3977                 4.9041
#
#       nota_bruta_-_ce  nota_padronizada_-_ce  conceito_enade_(continuo)  \
# 0             57.8000                 3.1363                     3.0415
# 1             55.7282                 2.7652                     2.7336
# 2             59.0025                 3.3516                     3.5312
# 3             56.9667                 2.9870                     3.0542
# 4             51.7800                 2.0580                     2.2634
# ...               ...                    ...                        ...
# 8336          40.3500                 1.9868                     2.0254
# 8337          39.9190                 1.9165                     2.0347
# 8338          37.5515                 1.5300                     1.8701
# 8339          42.1600                 5.0000                     4.7024
# 8353          40.6488                 4.4626                     4.5730
#
#       conceito_enade_(faixa)  observacao
# 0                          4         NaN
# 1                          3         NaN
# 2                          4         NaN
# 3                          4         NaN
# 4                          3         NaN
# ...                      ...         ...
# 8336                       3         NaN
# 8337                       3         NaN
# 8338                       2         NaN
# 8339                       5         NaN
# 8353                       5         NaN
#
# [1973 rows x 22 columns]

# %% [markdown]
# #### Criação do novo dataframe

# %%
colunas_desejadas = ['codigo_do_curso', 'conceito_enade_(faixa)']
enade_final = enade_filtrado[colunas_desejadas]

# %%
enade_final
# Out:
#       codigo_do_curso  conceito_enade_(faixa)
# 0                  37                       4
# 1              100763                       3
# 2               18031                       4
# 3             1108067                       4
# 4             1321453                       3
# ...               ...                     ...
# 8336          1146839                       3
# 8337          1186268                       3
# 8338          1208279                       2
# 8339          1428361                       5
# 8353           123116                       5
#
# [1973 rows x 2 columns]

# %%
enade_final.rename({'codigo_do_curso': 'co_curso'}, axis=1, inplace=True)
enade_final.rename({'conceito_enade_(faixa)': 'enade_faixa'}, axis=1, inplace=True)
# Out:
# C:\Users\thami\AppData\Local\Temp\ipykernel_12296\3048975398.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   enade_final.rename({'codigo_do_curso': 'co_curso'}, axis=1, inplace=True)
# C:\Users\thami\AppData\Local\Temp\ipykernel_12296\3048975398.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   enade_final.rename({'conceito_enade_(faixa)': 'enade_faixa'}, axis=1, inplace=True)

# %%
enade_final['co_curso'] = enade_final['co_curso'].astype(int)
# Out:
# C:\Users\thami\AppData\Local\Temp\ipykernel_12296\500858186.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   enade_final['co_curso'] = enade_final['co_curso'].astype(int)

# %%
enade_final.reset_index(drop=True, inplace=True)

# %%
enade_final
# Out:
#       co_curso  enade_faixa
# 0           37            4
# 1       100763            3
# 2        18031            4
# 3      1108067            4
# 4      1321453            3
# ...        ...          ...
# 1968   1146839            3
# 1969   1186268            3
# 1970   1208279            2
# 1971   1428361            5
# 1972    123116            5
#
# [1973 rows x 2 columns]

# %% [markdown]
# #### Gravação dos dados em CSV

# %%
enade_final.to_csv('dados_processados/enade_2019.csv', index=False)
