# %%
import pandas as pd
from unidecode import unidecode
#from pandas_profiling import ProfileReport quebrado

# %%
excel_file_path_enade = 'dados/conceito_enade_2021.xlsx'
enade = pd.read_excel(excel_file_path_enade)

# %% [markdown]
# # Enade

# %% [markdown]
# ### Funções

# %%
def remove_acentos(texto):
    return unidecode(str(texto))

# %%
def minusculo(texto):
    texto = texto.strip()
    texto = texto.replace('*', '')
    texto = texto.replace(' ', '_')
    return str(texto).lower()

# %%
def is_inteiro(valor):
    try:
        int_valor = int(valor)
        return True
    except (ValueError, TypeError):
        return False

# %% [markdown]
# ### Análise e limpeza dos dados

# %%
enade
# Out:
#                                                     Ano  Código da Área  \
# 0                                                  2021          2501.0
# 1                                                  2021          2501.0
# 2                                                  2021          2501.0
# 3                                                  2021          2501.0
# 4                                                  2021          2501.0
# ...                                                 ...             ...
# 7995                                               2021            79.0
# 7996                                               2021            79.0
# 7997                                                NaN             NaN
# 7998  * Nome e Sigla da IES atualizados na data da d...             NaN
# 7999  ** Para os cursos na modalidade a distância, o...             NaN
#
#                         Área de Avaliação Grau Acadêmico  Código da IES  \
# 0                          ARTES VISUAIS    Licenciatura            2.0
# 1                          ARTES VISUAIS    Licenciatura            2.0
# 2                          ARTES VISUAIS    Licenciatura            3.0
# 3                          ARTES VISUAIS    Licenciatura            4.0
# 4                          ARTES VISUAIS    Licenciatura            4.0
# ...                                   ...            ...            ...
# 7995  TECNOLOGIA EM REDES DE COMPUTADORES    Tecnológico        15689.0
# 7996  TECNOLOGIA EM REDES DE COMPUTADORES    Tecnológico        15709.0
# 7997                                  NaN            NaN            NaN
# 7998                                  NaN            NaN            NaN
# 7999                                  NaN            NaN            NaN
#
#                                            Nome da IES*  \
# 0                              UNIVERSIDADE DE BRASÍLIA
# 1                              UNIVERSIDADE DE BRASÍLIA
# 2                       UNIVERSIDADE FEDERAL DE SERGIPE
# 3                      UNIVERSIDADE FEDERAL DO AMAZONAS
# 4                      UNIVERSIDADE FEDERAL DO AMAZONAS
# ...                                                 ...
# 7995                   Faculdade de Tecnologia de Bauru
# 7996  Faculdade de Tecnologia de Osasco - Prefeito H...
# 7997                                                NaN
# 7998                                                NaN
# 7999                                                NaN
#
#                                     Sigla da IES* Organização Acadêmica  \
# 0                                             UNB          Universidade
# 1                                             UNB          Universidade
# 2                                             UFS          Universidade
# 3                                            UFAM          Universidade
# 4                                            UFAM          Universidade
# ...                                           ...                   ...
# 7995                                        FATEC             Faculdade
# 7996                                 Fatec Osasco             Faculdade
# 7997                                          NaN                   NaN
# 7998                                          NaN                   NaN
# 7999  do município/UF representa  sede do curso.                    NaN
#
#      Categoria Administrativa  Código do Curso  ... Sigla da UF**   \
# 0             Pública Federal            151.0  ...             DF
# 1             Pública Federal          52159.0  ...             DF
# 2             Pública Federal          80419.0  ...             SE
# 3             Pública Federal          62512.0  ...             AM
# 4             Pública Federal         112126.0  ...             AM
# ...                       ...              ...  ...            ...
# 7995         Pública Estadual        1149804.0  ...             SP
# 7996         Pública Estadual        1177589.0  ...             SP
# 7997                      NaN              NaN  ...            NaN
# 7998                      NaN              NaN  ...            NaN
# 7999                      NaN              NaN  ...            NaN
#
#       Nº de Concluintes Inscritos Nº  de Concluintes Participantes  \
# 0                            54.0                             41.0
# 1                            34.0                             28.0
# 2                            33.0                             33.0
# 3                            27.0                             23.0
# 4                            65.0                             59.0
# ...                           ...                              ...
# 7995                         35.0                             31.0
# 7996                        118.0                             82.0
# 7997                          NaN                              NaN
# 7998                          NaN                              NaN
# 7999                          NaN                              NaN
#
#      Nota Bruta - FG  Nota Padronizada - FG  Nota Bruta - CE  \
# 0             45.814                  3.771           61.907
# 1             40.496                  2.988           51.514
# 2             36.445                  2.392           51.121
# 3             43.569                  3.441           54.447
# 4             25.818                  0.828           33.503
# ...              ...                    ...              ...
# 7995          31.777                  2.629           26.693
# 7996          32.909                  2.808           31.782
# 7997             NaN                    NaN              NaN
# 7998             NaN                    NaN              NaN
# 7999             NaN                    NaN              NaN
#
#       Nota Padronizada - CE  Conceito Enade (Contínuo)  \
# 0                     3.947                      3.903
# 1                     2.640                      2.727
# 2                     2.590                      2.541
# 3                     3.009                      3.117
# 4                     0.374                      0.488
# ...                     ...                        ...
# 7995                  2.018                      2.171
# 7996                  2.690                      2.720
# 7997                    NaN                        NaN
# 7998                    NaN                        NaN
# 7999                    NaN                        NaN
#
#       Conceito Enade (Faixa)  Observação
# 0                          4         NaN
# 1                          3         NaN
# 2                          3         NaN
# 3                          4         NaN
# 4                          1         NaN
# ...                      ...         ...
# 7995                       3         NaN
# 7996                       3         NaN
# 7997                     NaN         NaN
# 7998                     NaN         NaN
# 7999                     NaN         NaN
#
# [8000 rows x 23 columns]

# %% [markdown]
# #### Ajustando nomes das colunas e linhas

# %%
colunas = enade.columns
for coluna in colunas:
    print(coluna)
# Out:
# Ano
# Código da Área
# Área de Avaliação
# Grau Acadêmico
# Código da IES
# Nome da IES*
# Sigla da IES*
# Organização Acadêmica
# Categoria Administrativa
# Código do Curso
# Modalidade de Ensino
# Código do Município**
# Município do Curso**
# Sigla da UF**
# Nº de Concluintes Inscritos
# Nº  de Concluintes Participantes
# Nota Bruta - FG
# Nota Padronizada - FG
# Nota Bruta - CE
# Nota Padronizada - CE
# Conceito Enade (Contínuo)
# Conceito Enade (Faixa)
# Observação

# %%
enade.columns = [minusculo(remove_acentos(col)) for col in enade.columns]

# %%
colunas_categoricas = enade.select_dtypes(include=['object']).columns
for coluna in colunas_categoricas:
    enade[coluna] = enade[coluna].apply(remove_acentos)
    enade[coluna] = enade[coluna].apply(minusculo)

# %%
colunas = enade.columns
for coluna in colunas:
    print(coluna)
# Out:
# ano
# codigo_da_area
# area_de_avaliacao
# grau_academico
# codigo_da_ies
# nome_da_ies
# sigla_da_ies
# organizacao_academica
# categoria_administrativa
# codigo_do_curso
# modalidade_de_ensino
# codigo_do_municipio
# municipio_do_curso
# sigla_da_uf
# no_de_concluintes_inscritos
# no__de_concluintes_participantes
# nota_bruta_-_fg
# nota_padronizada_-_fg
# nota_bruta_-_ce
# nota_padronizada_-_ce
# conceito_enade_(continuo)
# conceito_enade_(faixa)
# observacao

# %% [markdown]
# #### Ajustando dados da coluna conceito_enade_(faixa)

# %%
enade.shape
# Out:
# (8000, 23)

# %%
enade['conceito_enade_(faixa)'].unique()
# Out:
# array(['4', '3', '1', '5', '2', 'sc', 'nan'], dtype=object)

# %%
# Limpando os dados para só manter as linhas em que 'conceito_enade_(faixa)' é inteiro
enade = enade[enade['conceito_enade_(faixa)'].apply(is_inteiro)]
enade['conceito_enade_(faixa)'] = enade['conceito_enade_(faixa)'].astype(int)
# Out:
# C:\Users\thami\AppData\Local\Temp\ipykernel_1092\3078312973.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   enade['conceito_enade_(faixa)'] = enade['conceito_enade_(faixa)'].astype(int)

# %%
enade['conceito_enade_(faixa)'].unique()
# Out:
# array([4, 3, 1, 5, 2])

# %%
enade.shape
# Out:
# (7512, 23)

# %% [markdown]
# #### Ajustando dados da coluna ano

# %%
enade.shape
# Out:
# (7512, 23)

# %%
enade['ano'].unique()
# Out:
# array(['2021'], dtype=object)

# %%
# Limpando todos os dados que não seja do ano de 2021
enade_filtrado = enade.loc[enade['ano'] == '2021']

# %%
enade_filtrado['ano'].unique()
# Out:
# array(['2021'], dtype=object)

# %%
enade.shape
# Out:
# (7512, 23)

# %% [markdown]
# #### Ajustando dados da coluna modalidade_de_ensino

# %%
enade_filtrado['modalidade_de_ensino'].unique()
# Out:
# array(['educacao_presencial', 'educacao_a_distancia'], dtype=object)

# %%
enade_filtrado.shape
# Out:
# (7512, 23)

# %%
enade_filtrado = enade_filtrado.loc[enade_filtrado['modalidade_de_ensino'] == 'educacao_presencial']

# %%
enade_filtrado['modalidade_de_ensino'].unique()
# Out:
# array(['educacao_presencial'], dtype=object)

# %%
enade_filtrado.shape
# Out:
# (6588, 23)

# %%
enade_filtrado
# Out:
#        ano  codigo_da_area                    area_de_avaliacao  \
# 0     2021          2501.0                        artes_visuais
# 1     2021          2501.0                        artes_visuais
# 2     2021          2501.0                        artes_visuais
# 3     2021          2501.0                        artes_visuais
# 5     2021          2501.0                        artes_visuais
# ...    ...             ...                                  ...
# 7992  2021            79.0  tecnologia_em_redes_de_computadores
# 7993  2021            79.0  tecnologia_em_redes_de_computadores
# 7994  2021            79.0  tecnologia_em_redes_de_computadores
# 7995  2021            79.0  tecnologia_em_redes_de_computadores
# 7996  2021            79.0  tecnologia_em_redes_de_computadores
#
#      grau_academico  codigo_da_ies  \
# 0      licenciatura            2.0
# 1      licenciatura            2.0
# 2      licenciatura            3.0
# 3      licenciatura            4.0
# 5      licenciatura            4.0
# ...             ...            ...
# 7992    tecnologico        15236.0
# 7993    tecnologico        15520.0
# 7994    tecnologico        15522.0
# 7995    tecnologico        15689.0
# 7996    tecnologico        15709.0
#
#                                             nome_da_ies  sigla_da_ies  \
# 0                              universidade_de_brasilia           unb
# 1                              universidade_de_brasilia           unb
# 2                       universidade_federal_de_sergipe           ufs
# 3                      universidade_federal_do_amazonas          ufam
# 5                      universidade_federal_do_amazonas          ufam
# ...                                                 ...           ...
# 7992               faculdade_de_tecnologia_alcides_maya         amtec
# 7993  instituto_federal_de_educacao,_ciencia_e_tecno...          ifms
# 7994  instituto_federal_de_educacao,_ciencia_e_tecno...          ifap
# 7995                   faculdade_de_tecnologia_de_bauru         fatec
# 7996  faculdade_de_tecnologia_de_osasco_-_prefeito_h...  fatec_osasco
#
#                                   organizacao_academica  \
# 0                                          universidade
# 1                                          universidade
# 2                                          universidade
# 3                                          universidade
# 5                                          universidade
# ...                                                 ...
# 7992                                          faculdade
# 7993  instituto_federal_de_educacao,_ciencia_e_tecno...
# 7994  instituto_federal_de_educacao,_ciencia_e_tecno...
# 7995                                          faculdade
# 7996                                          faculdade
#
#          categoria_administrativa  codigo_do_curso  ... sigla_da_uf  \
# 0                 publica_federal            151.0  ...          df
# 1                 publica_federal          52159.0  ...          df
# 2                 publica_federal          80419.0  ...          se
# 3                 publica_federal          62512.0  ...          am
# 5                 publica_federal        1103469.0  ...          am
# ...                           ...              ...  ...         ...
# 7992  privada_com_fins_lucrativos        1134540.0  ...          rs
# 7993              publica_federal        1419849.0  ...          ms
# 7994              publica_federal        1168520.0  ...          ap
# 7995             publica_estadual        1149804.0  ...          sp
# 7996             publica_estadual        1177589.0  ...          sp
#
#       no_de_concluintes_inscritos no__de_concluintes_participantes  \
# 0                            54.0                             41.0
# 1                            34.0                             28.0
# 2                            33.0                             33.0
# 3                            27.0                             23.0
# 5                            25.0                             20.0
# ...                           ...                              ...
# 7992                          8.0                              6.0
# 7993                          8.0                              6.0
# 7994                         15.0                             11.0
# 7995                         35.0                             31.0
# 7996                        118.0                             82.0
#
#      nota_bruta_-_fg  nota_padronizada_-_fg  nota_bruta_-_ce  \
# 0             45.814                  3.771           61.907
# 1             40.496                  2.988           51.514
# 2             36.445                  2.392           51.121
# 3             43.569                  3.441           54.447
# 5             23.215                  0.445           30.525
# ...              ...                    ...              ...
# 7992          26.200                  1.745           32.133
# 7993          18.366                  0.505           29.550
# 7994          35.336                  3.192           26.936
# 7995          31.777                  2.629           26.693
# 7996          32.909                  2.808           31.782
#
#       nota_padronizada_-_ce  conceito_enade_(continuo)  \
# 0                     3.947                      3.903
# 1                     2.640                      2.727
# 2                     2.590                      2.541
# 3                     3.009                      3.117
# 5                     0.000                      0.111
# ...                     ...                        ...
# 7992                  2.737                      2.489
# 7993                  2.396                      1.923
# 7994                  2.051                      2.336
# 7995                  2.018                      2.171
# 7996                  2.690                      2.720
#
#       conceito_enade_(faixa)  observacao
# 0                          4         nan
# 1                          3         nan
# 2                          3         nan
# 3                          4         nan
# 5                          1         nan
# ...                      ...         ...
# 7992                       3         nan
# 7993                       2         nan
# 7994                       3         nan
# 7995                       3         nan
# 7996                       3         nan
#
# [6588 rows x 23 columns]

# %% [markdown]
# #### Ajustando dados da coluna categoria_administrativa

# %%
enade_filtrado['categoria_administrativa'].unique()
# Out:
# array(['publica_federal', 'publica_estadual',
#        'privada_sem_fins_lucrativos', 'publica_municipal',
#        'privada_com_fins_lucrativos', 'especial'], dtype=object)

# %%
enade_filtrado.shape
# Out:
# (6588, 23)

# %%
categorias_desejadas = ['publica_federal', 'publica_estadual', 'publica_municipal']
enade_filtrado = enade_filtrado[enade_filtrado['categoria_administrativa'].isin(categorias_desejadas)]

# %%
enade_filtrado['categoria_administrativa'].unique()
# Out:
# array(['publica_federal', 'publica_estadual', 'publica_municipal'],
#       dtype=object)

# %%
enade_filtrado.shape
# Out:
# (3232, 23)

# %%
enade_filtrado
# Out:
#        ano  codigo_da_area                    area_de_avaliacao  \
# 0     2021          2501.0                        artes_visuais
# 1     2021          2501.0                        artes_visuais
# 2     2021          2501.0                        artes_visuais
# 3     2021          2501.0                        artes_visuais
# 5     2021          2501.0                        artes_visuais
# ...    ...             ...                                  ...
# 7987  2021            79.0  tecnologia_em_redes_de_computadores
# 7993  2021            79.0  tecnologia_em_redes_de_computadores
# 7994  2021            79.0  tecnologia_em_redes_de_computadores
# 7995  2021            79.0  tecnologia_em_redes_de_computadores
# 7996  2021            79.0  tecnologia_em_redes_de_computadores
#
#      grau_academico  codigo_da_ies  \
# 0      licenciatura            2.0
# 1      licenciatura            2.0
# 2      licenciatura            3.0
# 3      licenciatura            4.0
# 5      licenciatura            4.0
# ...             ...            ...
# 7987    tecnologico         5036.0
# 7993    tecnologico        15520.0
# 7994    tecnologico        15522.0
# 7995    tecnologico        15689.0
# 7996    tecnologico        15709.0
#
#                                             nome_da_ies    sigla_da_ies  \
# 0                              universidade_de_brasilia             unb
# 1                              universidade_de_brasilia             unb
# 2                       universidade_federal_de_sergipe             ufs
# 3                      universidade_federal_do_amazonas            ufam
# 5                      universidade_federal_do_amazonas            ufam
# ...                                                 ...             ...
# 7987  instituto_federal_de_educacao,_ciencia_e_tecno...  if_catarinense
# 7993  instituto_federal_de_educacao,_ciencia_e_tecno...            ifms
# 7994  instituto_federal_de_educacao,_ciencia_e_tecno...            ifap
# 7995                   faculdade_de_tecnologia_de_bauru           fatec
# 7996  faculdade_de_tecnologia_de_osasco_-_prefeito_h...    fatec_osasco
#
#                                   organizacao_academica  \
# 0                                          universidade
# 1                                          universidade
# 2                                          universidade
# 3                                          universidade
# 5                                          universidade
# ...                                                 ...
# 7987  instituto_federal_de_educacao,_ciencia_e_tecno...
# 7993  instituto_federal_de_educacao,_ciencia_e_tecno...
# 7994  instituto_federal_de_educacao,_ciencia_e_tecno...
# 7995                                          faculdade
# 7996                                          faculdade
#
#      categoria_administrativa  codigo_do_curso  ... sigla_da_uf  \
# 0             publica_federal            151.0  ...          df
# 1             publica_federal          52159.0  ...          df
# 2             publica_federal          80419.0  ...          se
# 3             publica_federal          62512.0  ...          am
# 5             publica_federal        1103469.0  ...          am
# ...                       ...              ...  ...         ...
# 7987          publica_federal        1377572.0  ...          sc
# 7993          publica_federal        1419849.0  ...          ms
# 7994          publica_federal        1168520.0  ...          ap
# 7995         publica_estadual        1149804.0  ...          sp
# 7996         publica_estadual        1177589.0  ...          sp
#
#       no_de_concluintes_inscritos no__de_concluintes_participantes  \
# 0                            54.0                             41.0
# 1                            34.0                             28.0
# 2                            33.0                             33.0
# 3                            27.0                             23.0
# 5                            25.0                             20.0
# ...                           ...                              ...
# 7987                         10.0                              6.0
# 7993                          8.0                              6.0
# 7994                         15.0                             11.0
# 7995                         35.0                             31.0
# 7996                        118.0                             82.0
#
#      nota_bruta_-_fg  nota_padronizada_-_fg  nota_bruta_-_ce  \
# 0             45.814                  3.771           61.907
# 1             40.496                  2.988           51.514
# 2             36.445                  2.392           51.121
# 3             43.569                  3.441           54.447
# 5             23.215                  0.445           30.525
# ...              ...                    ...              ...
# 7987          43.933                  4.553           41.900
# 7993          18.366                  0.505           29.550
# 7994          35.336                  3.192           26.936
# 7995          31.777                  2.629           26.693
# 7996          32.909                  2.808           31.782
#
#       nota_padronizada_-_ce  conceito_enade_(continuo)  \
# 0                     3.947                      3.903
# 1                     2.640                      2.727
# 2                     2.590                      2.541
# 3                     3.009                      3.117
# 5                     0.000                      0.111
# ...                     ...                        ...
# 7987                  4.026                      4.158
# 7993                  2.396                      1.923
# 7994                  2.051                      2.336
# 7995                  2.018                      2.171
# 7996                  2.690                      2.720
#
#       conceito_enade_(faixa)  observacao
# 0                          4         nan
# 1                          3         nan
# 2                          3         nan
# 3                          4         nan
# 5                          1         nan
# ...                      ...         ...
# 7987                       5         nan
# 7993                       2         nan
# 7994                       3         nan
# 7995                       3         nan
# 7996                       3         nan
#
# [3232 rows x 23 columns]

# %% [markdown]
# #### Criação do novo dataframe

# %%
colunas_desejadas = ['grau_academico', 'codigo_do_curso', 'conceito_enade_(faixa)']
enade_final = enade_filtrado[colunas_desejadas]

# %%
enade_final
# Out:
#      grau_academico  codigo_do_curso  conceito_enade_(faixa)
# 0      licenciatura            151.0                       4
# 1      licenciatura          52159.0                       3
# 2      licenciatura          80419.0                       3
# 3      licenciatura          62512.0                       4
# 5      licenciatura        1103469.0                       1
# ...             ...              ...                     ...
# 7987    tecnologico        1377572.0                       5
# 7993    tecnologico        1419849.0                       2
# 7994    tecnologico        1168520.0                       3
# 7995    tecnologico        1149804.0                       3
# 7996    tecnologico        1177589.0                       3
#
# [3232 rows x 3 columns]

# %%
enade_final.rename({'codigo_do_curso': 'co_curso'}, axis=1, inplace=True)
enade_final.rename({'conceito_enade_(faixa)': 'enade_faixa'}, axis=1, inplace=True)
enade_final.rename({'grau_academico': 'tp_grau_academico'}, axis=1, inplace=True)
# Out:
# C:\Users\thami\AppData\Local\Temp\ipykernel_1092\2306802004.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   enade_final.rename({'codigo_do_curso': 'co_curso'}, axis=1, inplace=True)
# C:\Users\thami\AppData\Local\Temp\ipykernel_1092\2306802004.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   enade_final.rename({'conceito_enade_(faixa)': 'enade_faixa'}, axis=1, inplace=True)
# C:\Users\thami\AppData\Local\Temp\ipykernel_1092\2306802004.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   enade_final.rename({'grau_academico': 'tp_grau_academico'}, axis=1, inplace=True)

# %%
enade_final['co_curso'] = enade_final['co_curso'].astype(int)
# Out:
# C:\Users\thami\AppData\Local\Temp\ipykernel_1092\500858186.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   enade_final['co_curso'] = enade_final['co_curso'].astype(int)

# %%
enade_final.reset_index(drop=True, inplace=True)

# %%
enade_final
# Out:
#      tp_grau_academico  co_curso  enade_faixa
# 0         licenciatura       151            4
# 1         licenciatura     52159            3
# 2         licenciatura     80419            3
# 3         licenciatura     62512            4
# 4         licenciatura   1103469            1
# ...                ...       ...          ...
# 3227       tecnologico   1377572            5
# 3228       tecnologico   1419849            2
# 3229       tecnologico   1168520            3
# 3230       tecnologico   1149804            3
# 3231       tecnologico   1177589            3
#
# [3232 rows x 3 columns]

# %% [markdown]
# #### Gravação dos dados em CSV

# %%
enade_final.to_csv('dados_processados/enade_final.csv', index=False)
