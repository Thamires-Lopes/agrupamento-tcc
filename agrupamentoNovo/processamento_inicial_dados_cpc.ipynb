# %%
import pandas as pd
from unidecode import unidecode
#from pandas_profiling import ProfileReport quebrado

# %%
excel_file_path_cpc = 'dados/resultados_cpc_2021.xlsx'
cpc = pd.read_excel(excel_file_path_cpc)

# %% [markdown]
# # CPC

# %% [markdown]
# ### Funções

# %%
def remove_acentos(texto):
    return unidecode(str(texto))

# %%
def minusculo(texto):
    texto = texto.strip()
    texto = texto.replace('*', '')
    texto = texto.replace(' ', '_')
    return str(texto).lower()

# %%
def is_inteiro(valor):
    try:
        int_valor = int(valor)
        return True
    except (ValueError, TypeError):
        return False

# %% [markdown]
# ### Análise e limpeza dos dados

# %%
cpc
# Out:
#                                                     Ano  Código da Área  \
# 0                                                  2021          2001.0
# 1                                                  2021          3502.0
# 2                                                  2021           702.0
# 3                                                  2021          1402.0
# 4                                                  2021          1602.0
# ...                                                 ...             ...
# 7996                                               2021          1601.0
# 7997                                                NaN             NaN
# 7998  * Nome, sigla, Organização Acadêmica, Categori...             NaN
# 7999  ** Os resultados dos indicadores de Qualidade ...             NaN
# 8000  *** Para os cursos na modalidade a distância, ...             NaN
#
#                        Área de Avaliação Grau acadêmico  Código da IES*  \
# 0               PEDAGOGIA (LICENCIATURA)   Licenciatura             1.0
# 1         EDUCAÇÃO FÍSICA (LICENCIATURA)   Licenciatura             1.0
# 2              MATEMÁTICA (LICENCIATURA)   Licenciatura             1.0
# 3                  FÍSICA (LICENCIATURA)   Licenciatura             1.0
# 4     CIÊNCIAS BIOLÓGICAS (LICENCIATURA)   Licenciatura             1.0
# ...                                  ...            ...             ...
# 7996   CIÊNCIAS BIOLÓGICAS (BACHARELADO)    Bacharelado         25352.0
# 7997                                 NaN            NaN             NaN
# 7998                                 NaN            NaN             NaN
# 7999                                 NaN            NaN             NaN
# 8000                                 NaN            NaN             NaN
#
#                               Nome da IES* Sigla da IES*  \
# 0      UNIVERSIDADE FEDERAL DE MATO GROSSO          UFMT
# 1      UNIVERSIDADE FEDERAL DE MATO GROSSO          UFMT
# 2      UNIVERSIDADE FEDERAL DE MATO GROSSO          UFMT
# 3      UNIVERSIDADE FEDERAL DE MATO GROSSO          UFMT
# 4      UNIVERSIDADE FEDERAL DE MATO GROSSO          UFMT
# ...                                    ...           ...
# 7996  Universidade Federal de Rondonópolis           UFR
# 7997                                   NaN           NaN
# 7998                                   NaN           NaN
# 7999                                   NaN           NaN
# 8000                                   NaN           NaN
#
#      Organização Acadêmica* Categoria Administrativa*  Código do Curso**  ...  \
# 0              Universidade           Pública Federal                6.0  ...
# 1              Universidade           Pública Federal               19.0  ...
# 2              Universidade           Pública Federal               26.0  ...
# 3              Universidade           Pública Federal               27.0  ...
# 4              Universidade           Pública Federal               29.0  ...
# ...                     ...                       ...                ...  ...
# 7996           Universidade           Pública Federal          1188880.0  ...
# 7997                    NaN                       NaN                NaN  ...
# 7998                    NaN                       NaN                NaN  ...
# 7999                    NaN                       NaN                NaN  ...
# 8000                    NaN                       NaN                NaN  ...
#
#       Nota Padronizada - Oportunidade de Ampliação da Formação  \
# 0                                                 1.916
# 1                                                 4.071
# 2                                                 3.161
# 3                                                 3.201
# 4                                                 2.699
# ...                                                 ...
# 7996                                              2.635
# 7997                                                NaN
# 7998                                                NaN
# 7999                                                NaN
# 8000                                                NaN
#
#        Nota Bruta - Mestres  Nota Padronizada - Mestres  \
# 0                     0.979                       4.852
# 1                     1.000                       5.000
# 2                     1.000                       5.000
# 3                     1.000                       5.000
# 4                     1.000                       5.000
# ...                     ...                         ...
# 7996                  0.956                       4.173
# 7997                    NaN                         NaN
# 7998                    NaN                         NaN
# 7999                    NaN                         NaN
# 8000                    NaN                         NaN
#
#       Nota Bruta - Doutores   Nota Padronizada - Doutores  \
# 0                     0.857                         4.285
# 1                     0.923                         4.615
# 2                     0.868                         4.342
# 3                     0.923                         4.615
# 4                     0.928                         4.642
# ...                     ...                           ...
# 7996                  0.826                         3.840
# 7997                    NaN                           NaN
# 7998                    NaN                           NaN
# 7999                    NaN                           NaN
# 8000                    NaN                           NaN
#
#        Nota Bruta – Regime de Trabalho  \
# 0                                  1.0
# 1                                  1.0
# 2                                  1.0
# 3                                  1.0
# 4                                  1.0
# ...                                ...
# 7996                               1.0
# 7997                               NaN
# 7998                               NaN
# 7999                               NaN
# 8000                               NaN
#
#        Nota Padronizada - Regime de Trabalho   CPC (Contínuo)   CPC (Faixa)  \
# 0                                        5.0            3.955             4
# 1                                        5.0            3.383             4
# 2                                        5.0            2.875             3
# 3                                        5.0            2.691             3
# 4                                        5.0            3.263             4
# ...                                      ...              ...           ...
# 7996                                     5.0            3.039             4
# 7997                                     NaN              NaN           NaN
# 7998                                     NaN              NaN           NaN
# 7999                                     NaN              NaN           NaN
# 8000                                     NaN              NaN           NaN
#
#       Observação
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 7996         NaN
# 7997         NaN
# 7998         NaN
# 7999         NaN
# 8000         NaN
#
# [8001 rows x 40 columns]

# %% [markdown]
# #### Ajustando nomes das colunas e linhas

# %%
colunas = cpc.columns
for coluna in colunas:
    print(coluna)
# Out:
# Ano
# Código da Área
# Área de Avaliação
# Grau acadêmico
# Código da IES*
# Nome da IES*
# Sigla da IES*
# Organização Acadêmica*
# Categoria Administrativa*
# Código do Curso**
# Modalidade de Ensino***
# Código do Município***
# Município do Curso***
# Sigla da UF**
#  Nº de Concluintes Inscritos
#  Nº de Concluintes Participantes
#  Nota Bruta - FG
#  Nota Padronizada - FG
#  Nota Bruta - CE
#  Nota Padronizada - CE
#  Conceito Enade (Contínuo)
#  Concluintes participantes com nota no Enem
#  Proporção de concluintes participantes com nota no Enem
#  Nota Bruta - IDD
#  Nota Padronizada - IDD
#  Nota Bruta – Organização Didático-Pedagógica
#  Nota Padronizada - Organização Didático-Pedagógica
#  Nota Bruta – Infraestrutura e Instalações Físicas
#  Nota Padronizada - Infraestrutura e Instalações Físicas
#  Nota Bruta – Oportunidade de Ampliação da Formação
#  Nota Padronizada - Oportunidade de Ampliação da Formação
#  Nota Bruta - Mestres
#  Nota Padronizada - Mestres
#  Nota Bruta - Doutores
#  Nota Padronizada - Doutores
#  Nota Bruta – Regime de Trabalho
#  Nota Padronizada - Regime de Trabalho
#  CPC (Contínuo)
#  CPC (Faixa)
# Observação

# %%
cpc.columns = [minusculo(remove_acentos(col)) for col in cpc.columns]

# %%
colunas_categoricas = cpc.select_dtypes(include=['object']).columns
for coluna in colunas_categoricas:
    cpc[coluna] = cpc[coluna].apply(remove_acentos)
    cpc[coluna] = cpc[coluna].apply(minusculo)

# %%
colunas = cpc.columns
for coluna in colunas:
    print(coluna)
# Out:
# ano
# codigo_da_area
# area_de_avaliacao
# grau_academico
# codigo_da_ies
# nome_da_ies
# sigla_da_ies
# organizacao_academica
# categoria_administrativa
# codigo_do_curso
# modalidade_de_ensino
# codigo_do_municipio
# municipio_do_curso
# sigla_da_uf
# no_de_concluintes_inscritos
# no_de_concluintes_participantes
# nota_bruta_-_fg
# nota_padronizada_-_fg
# nota_bruta_-_ce
# nota_padronizada_-_ce
# conceito_enade_(continuo)
# concluintes_participantes_com_nota_no_enem
# proporcao_de_concluintes_participantes_com_nota_no_enem
# nota_bruta_-_idd
# nota_padronizada_-_idd
# nota_bruta_-_organizacao_didatico-pedagogica
# nota_padronizada_-_organizacao_didatico-pedagogica
# nota_bruta_-_infraestrutura_e_instalacoes_fisicas
# nota_padronizada_-_infraestrutura_e_instalacoes_fisicas
# nota_bruta_-_oportunidade_de_ampliacao_da_formacao
# nota_padronizada_-_oportunidade_de_ampliacao_da_formacao
# nota_bruta_-_mestres
# nota_padronizada_-_mestres
# nota_bruta_-_doutores
# nota_padronizada_-_doutores
# nota_bruta_-_regime_de_trabalho
# nota_padronizada_-_regime_de_trabalho
# cpc_(continuo)
# cpc_(faixa)
# observacao

# %% [markdown]
# #### Ajustando dados da coluna conceito_enade_(faixa)

# %%
cpc.shape
# Out:
# (8001, 40)

# %%
cpc['cpc_(faixa)'].unique()
# Out:
# array(['4', '3', 'sc', '2', '5', '1', 'nan'], dtype=object)

# %%
# Limpando os dados para só manter as linhas em que 'cpc_(faixa)' é inteiro
cpc = cpc[cpc['cpc_(faixa)'].apply(is_inteiro)]
cpc['cpc_(faixa)'] = cpc['cpc_(faixa)'].astype(int)
# Out:
# C:\Users\thami\AppData\Local\Temp\ipykernel_8600\2942167432.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cpc['cpc_(faixa)'] = cpc['cpc_(faixa)'].astype(int)

# %%
cpc['cpc_(faixa)'].unique()
# Out:
# array([4, 3, 2, 5, 1])

# %%
cpc.shape
# Out:
# (7512, 40)

# %% [markdown]
# #### Ajustando dados da coluna ano

# %%
# Não há mudança com a utilização desse trecho de código, porém irei manter para ficar padronizado com o códio do Enade

# %%
cpc.shape
# Out:
# (7512, 40)

# %%
cpc['ano'].unique()
# Out:
# array(['2021'], dtype=object)

# %%
# Limpando todos os dados que não seja do ano de 2021
cpc_filtrado = cpc.loc[cpc['ano'] == '2021']

# %%
cpc_filtrado['ano'].unique()
# Out:
# array(['2021'], dtype=object)

# %%
cpc.shape
# Out:
# (7512, 40)

# %% [markdown]
# #### Ajustando dados da coluna modalidade_de_ensino

# %%
cpc_filtrado['modalidade_de_ensino'].unique()
# Out:
# array(['educacao_presencial', 'educacao_a_distancia'], dtype=object)

# %%
cpc_filtrado.shape
# Out:
# (7512, 40)

# %%
cpc_filtrado = cpc_filtrado.loc[cpc_filtrado['modalidade_de_ensino'] == 'educacao_presencial']

# %%
cpc_filtrado['modalidade_de_ensino'].unique()
# Out:
# array(['educacao_presencial'], dtype=object)

# %%
cpc_filtrado.shape
# Out:
# (6588, 40)

# %%
cpc_filtrado
# Out:
#        ano  codigo_da_area                   area_de_avaliacao grau_academico  \
# 0     2021          2001.0            pedagogia_(licenciatura)   licenciatura
# 1     2021          3502.0      educacao_fisica_(licenciatura)   licenciatura
# 2     2021           702.0           matematica_(licenciatura)   licenciatura
# 3     2021          1402.0               fisica_(licenciatura)   licenciatura
# 4     2021          1602.0  ciencias_biologicas_(licenciatura)   licenciatura
# ...    ...             ...                                 ...            ...
# 7991  2021          1602.0  ciencias_biologicas_(licenciatura)   licenciatura
# 7992  2021           702.0           matematica_(licenciatura)   licenciatura
# 7994  2021          6407.0                     letras_-_ingles   licenciatura
# 7995  2021          4006.0              sistemas_de_informacao    bacharelado
# 7996  2021          1601.0   ciencias_biologicas_(bacharelado)    bacharelado
#
#       codigo_da_ies                           nome_da_ies sigla_da_ies  \
# 0               1.0   universidade_federal_de_mato_grosso         ufmt
# 1               1.0   universidade_federal_de_mato_grosso         ufmt
# 2               1.0   universidade_federal_de_mato_grosso         ufmt
# 3               1.0   universidade_federal_de_mato_grosso         ufmt
# 4               1.0   universidade_federal_de_mato_grosso         ufmt
# ...             ...                                   ...          ...
# 7991        25352.0  universidade_federal_de_rondonopolis          ufr
# 7992        25352.0  universidade_federal_de_rondonopolis          ufr
# 7994        25352.0  universidade_federal_de_rondonopolis          ufr
# 7995        25352.0  universidade_federal_de_rondonopolis          ufr
# 7996        25352.0  universidade_federal_de_rondonopolis          ufr
#
#      organizacao_academica categoria_administrativa  codigo_do_curso  ...  \
# 0             universidade          publica_federal              6.0  ...
# 1             universidade          publica_federal             19.0  ...
# 2             universidade          publica_federal             26.0  ...
# 3             universidade          publica_federal             27.0  ...
# 4             universidade          publica_federal             29.0  ...
# ...                    ...                      ...              ...  ...
# 7991          universidade          publica_federal             32.0  ...
# 7992          universidade          publica_federal             34.0  ...
# 7994          universidade          publica_federal         101054.0  ...
# 7995          universidade          publica_federal        1128077.0  ...
# 7996          universidade          publica_federal        1188880.0  ...
#
#      nota_padronizada_-_oportunidade_de_ampliacao_da_formacao  \
# 0                                                 1.916
# 1                                                 4.071
# 2                                                 3.161
# 3                                                 3.201
# 4                                                 2.699
# ...                                                 ...
# 7991                                              2.516
# 7992                                              2.211
# 7994                                              2.105
# 7995                                              2.987
# 7996                                              2.635
#
#       nota_bruta_-_mestres nota_padronizada_-_mestres nota_bruta_-_doutores  \
# 0                    0.979                      4.852                 0.857
# 1                    1.000                      5.000                 0.923
# 2                    1.000                      5.000                 0.868
# 3                    1.000                      5.000                 0.923
# 4                    1.000                      5.000                 0.928
# ...                    ...                        ...                   ...
# 7991                 0.954                      4.570                 0.681
# 7992                 0.960                      4.700                 0.680
# 7994                 0.933                      4.296                 0.733
# 7995                 0.760                      3.200                 0.560
# 7996                 0.956                      4.173                 0.826
#
#       nota_padronizada_-_doutores  nota_bruta_-_regime_de_trabalho  \
# 0                           4.285                              1.0
# 1                           4.615                              1.0
# 2                           4.342                              1.0
# 3                           4.615                              1.0
# 4                           4.642                              1.0
# ...                           ...                              ...
# 7991                        3.409                              1.0
# 7992                        3.400                              1.0
# 7994                        3.666                              1.0
# 7995                        2.800                              1.0
# 7996                        3.840                              1.0
#
#       nota_padronizada_-_regime_de_trabalho  cpc_(continuo)  cpc_(faixa)  \
# 0                                       5.0           3.955            4
# 1                                       5.0           3.383            4
# 2                                       5.0           2.875            3
# 3                                       5.0           2.691            3
# 4                                       5.0           3.263            4
# ...                                     ...             ...          ...
# 7991                                    5.0           2.539            3
# 7992                                    5.0           2.180            3
# 7994                                    5.0           3.230            4
# 7995                                    5.0           2.481            3
# 7996                                    5.0           3.039            4
#
#       observacao
# 0            nan
# 1            nan
# 2            nan
# 3            nan
# 4            nan
# ...          ...
# 7991         nan
# 7992         nan
# 7994         nan
# 7995         nan
# 7996         nan
#
# [6588 rows x 40 columns]

# %% [markdown]
# #### Ajustando dados da coluna categoria_administrativa

# %%
cpc_filtrado['categoria_administrativa'].unique()
# Out:
# array(['publica_federal', 'publica_estadual',
#        'privada_sem_fins_lucrativos', 'especial', 'publica_municipal',
#        'privada_com_fins_lucrativos'], dtype=object)

# %%
cpc_filtrado.shape
# Out:
# (6588, 40)

# %%
categorias_desejadas = ['publica_federal', 'publica_estadual', 'publica_municipal']
cpc_filtrado = cpc_filtrado[cpc_filtrado['categoria_administrativa'].isin(categorias_desejadas)]

# %%
cpc_filtrado['categoria_administrativa'].unique()
# Out:
# array(['publica_federal', 'publica_estadual', 'publica_municipal'],
#       dtype=object)

# %%
cpc_filtrado.shape
# Out:
# (3214, 40)

# %%
cpc_filtrado
# Out:
#        ano  codigo_da_area                   area_de_avaliacao grau_academico  \
# 0     2021          2001.0            pedagogia_(licenciatura)   licenciatura
# 1     2021          3502.0      educacao_fisica_(licenciatura)   licenciatura
# 2     2021           702.0           matematica_(licenciatura)   licenciatura
# 3     2021          1402.0               fisica_(licenciatura)   licenciatura
# 4     2021          1602.0  ciencias_biologicas_(licenciatura)   licenciatura
# ...    ...             ...                                 ...            ...
# 7991  2021          1602.0  ciencias_biologicas_(licenciatura)   licenciatura
# 7992  2021           702.0           matematica_(licenciatura)   licenciatura
# 7994  2021          6407.0                     letras_-_ingles   licenciatura
# 7995  2021          4006.0              sistemas_de_informacao    bacharelado
# 7996  2021          1601.0   ciencias_biologicas_(bacharelado)    bacharelado
#
#       codigo_da_ies                           nome_da_ies sigla_da_ies  \
# 0               1.0   universidade_federal_de_mato_grosso         ufmt
# 1               1.0   universidade_federal_de_mato_grosso         ufmt
# 2               1.0   universidade_federal_de_mato_grosso         ufmt
# 3               1.0   universidade_federal_de_mato_grosso         ufmt
# 4               1.0   universidade_federal_de_mato_grosso         ufmt
# ...             ...                                   ...          ...
# 7991        25352.0  universidade_federal_de_rondonopolis          ufr
# 7992        25352.0  universidade_federal_de_rondonopolis          ufr
# 7994        25352.0  universidade_federal_de_rondonopolis          ufr
# 7995        25352.0  universidade_federal_de_rondonopolis          ufr
# 7996        25352.0  universidade_federal_de_rondonopolis          ufr
#
#      organizacao_academica categoria_administrativa  codigo_do_curso  ...  \
# 0             universidade          publica_federal              6.0  ...
# 1             universidade          publica_federal             19.0  ...
# 2             universidade          publica_federal             26.0  ...
# 3             universidade          publica_federal             27.0  ...
# 4             universidade          publica_federal             29.0  ...
# ...                    ...                      ...              ...  ...
# 7991          universidade          publica_federal             32.0  ...
# 7992          universidade          publica_federal             34.0  ...
# 7994          universidade          publica_federal         101054.0  ...
# 7995          universidade          publica_federal        1128077.0  ...
# 7996          universidade          publica_federal        1188880.0  ...
#
#      nota_padronizada_-_oportunidade_de_ampliacao_da_formacao  \
# 0                                                 1.916
# 1                                                 4.071
# 2                                                 3.161
# 3                                                 3.201
# 4                                                 2.699
# ...                                                 ...
# 7991                                              2.516
# 7992                                              2.211
# 7994                                              2.105
# 7995                                              2.987
# 7996                                              2.635
#
#       nota_bruta_-_mestres nota_padronizada_-_mestres nota_bruta_-_doutores  \
# 0                    0.979                      4.852                 0.857
# 1                    1.000                      5.000                 0.923
# 2                    1.000                      5.000                 0.868
# 3                    1.000                      5.000                 0.923
# 4                    1.000                      5.000                 0.928
# ...                    ...                        ...                   ...
# 7991                 0.954                      4.570                 0.681
# 7992                 0.960                      4.700                 0.680
# 7994                 0.933                      4.296                 0.733
# 7995                 0.760                      3.200                 0.560
# 7996                 0.956                      4.173                 0.826
#
#       nota_padronizada_-_doutores  nota_bruta_-_regime_de_trabalho  \
# 0                           4.285                              1.0
# 1                           4.615                              1.0
# 2                           4.342                              1.0
# 3                           4.615                              1.0
# 4                           4.642                              1.0
# ...                           ...                              ...
# 7991                        3.409                              1.0
# 7992                        3.400                              1.0
# 7994                        3.666                              1.0
# 7995                        2.800                              1.0
# 7996                        3.840                              1.0
#
#       nota_padronizada_-_regime_de_trabalho  cpc_(continuo)  cpc_(faixa)  \
# 0                                       5.0           3.955            4
# 1                                       5.0           3.383            4
# 2                                       5.0           2.875            3
# 3                                       5.0           2.691            3
# 4                                       5.0           3.263            4
# ...                                     ...             ...          ...
# 7991                                    5.0           2.539            3
# 7992                                    5.0           2.180            3
# 7994                                    5.0           3.230            4
# 7995                                    5.0           2.481            3
# 7996                                    5.0           3.039            4
#
#       observacao
# 0            nan
# 1            nan
# 2            nan
# 3            nan
# 4            nan
# ...          ...
# 7991         nan
# 7992         nan
# 7994         nan
# 7995         nan
# 7996         nan
#
# [3214 rows x 40 columns]

# %% [markdown]
# #### Criação do novo dataframe

# %%
colunas_desejadas = ['grau_academico', 'codigo_do_curso', 'cpc_(faixa)']
cpc_final = cpc_filtrado[colunas_desejadas]

# %%
cpc_final
# Out:
#      grau_academico  codigo_do_curso  cpc_(faixa)
# 0      licenciatura              6.0            4
# 1      licenciatura             19.0            4
# 2      licenciatura             26.0            3
# 3      licenciatura             27.0            3
# 4      licenciatura             29.0            4
# ...             ...              ...          ...
# 7991   licenciatura             32.0            3
# 7992   licenciatura             34.0            3
# 7994   licenciatura         101054.0            4
# 7995    bacharelado        1128077.0            3
# 7996    bacharelado        1188880.0            4
#
# [3214 rows x 3 columns]

# %%
cpc_final.rename({'codigo_do_curso': 'co_curso'}, axis=1, inplace=True)
cpc_final.rename({'cpc_(faixa)': 'cpc_faixa'}, axis=1, inplace=True)
cpc_final.rename({'grau_academico': 'tp_grau_academico'}, axis=1, inplace=True)
# Out:
# C:\Users\thami\AppData\Local\Temp\ipykernel_8600\229336111.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cpc_final.rename({'codigo_do_curso': 'co_curso'}, axis=1, inplace=True)
# C:\Users\thami\AppData\Local\Temp\ipykernel_8600\229336111.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cpc_final.rename({'cpc_(faixa)': 'cpc_faixa'}, axis=1, inplace=True)
# C:\Users\thami\AppData\Local\Temp\ipykernel_8600\229336111.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cpc_final.rename({'grau_academico': 'tp_grau_academico'}, axis=1, inplace=True)

# %%
cpc_final['co_curso'] = cpc_final['co_curso'].astype(int)
# Out:
# C:\Users\thami\AppData\Local\Temp\ipykernel_8600\3286276137.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cpc_final['co_curso'] = cpc_final['co_curso'].astype(int)

# %%
cpc_final.reset_index(drop=True, inplace=True)

# %%
cpc_final
# Out:
#      tp_grau_academico  co_curso  cpc_faixa
# 0         licenciatura         6          4
# 1         licenciatura        19          4
# 2         licenciatura        26          3
# 3         licenciatura        27          3
# 4         licenciatura        29          4
# ...                ...       ...        ...
# 3209      licenciatura        32          3
# 3210      licenciatura        34          3
# 3211      licenciatura    101054          4
# 3212       bacharelado   1128077          3
# 3213       bacharelado   1188880          4
#
# [3214 rows x 3 columns]

# %% [markdown]
# #### Gravação dos dados em CSV

# %%
cpc_final.to_csv('dados_processados/cpc_final.csv', index=False)
